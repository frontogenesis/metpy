# %%
import xarray as xr

from metpy.cbook import get_test_data
from metpy.io import GiniFile
from metpy.plots import ImagePlot, MapPanel, PanelContainer
# Out:
# Downloading file 'sfstns.tbl' from 'https://github.com/Unidata/MetPy/raw/v0.12.1/staticdata/sfstns.tbl' to 'C:\Users\rayha\AppData\Local\metpy\metpy\Cache\v0.12.1'.
# Downloading file 'master.txt' from 'https://github.com/Unidata/MetPy/raw/v0.12.1/staticdata/master.txt' to 'C:\Users\rayha\AppData\Local\metpy\metpy\Cache\v0.12.1'.
# Downloading file 'stations.txt' from 'https://github.com/Unidata/MetPy/raw/v0.12.1/staticdata/stations.txt' to 'C:\Users\rayha\AppData\Local\metpy\metpy\Cache\v0.12.1'.
# Downloading file 'airport-codes.csv' from 'https://github.com/Unidata/MetPy/raw/v0.12.1/staticdata/airport-codes.csv' to 'C:\Users\rayha\AppData\Local\metpy\metpy\Cache\v0.12.1'.

# %%
data = xr.open_dataset(GiniFile(get_test_data('NHEM-MULTICOMP_1km_IR_20151208_2100.gini')))
# Out:
# Downloading file 'NHEM-MULTICOMP_1km_IR_20151208_2100.gini' from 'https://github.com/Unidata/MetPy/raw/v0.12.1/staticdata/NHEM-MULTICOMP_1km_IR_20151208_2100.gini' to 'C:\Users\rayha\AppData\Local\metpy\metpy\Cache\v0.12.1'.
# Adjusting bad PDB size from 0 to 512.

# %%
img = ImagePlot()
img.data = data
img.field = 'IR'
img.colormap = 'Greys_r'

panel = MapPanel()
panel.plots = [img]

pc = PanelContainer()
pc.panels = [panel]
pc.show()
